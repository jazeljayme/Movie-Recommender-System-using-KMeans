# %%
from bs4 import BeautifulSoup
import requests
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
url = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuAKB_5eJBsACAdICJDE2NWU4YTM3LTg5NjMtNDI2Yy05NWFiLTAzY2EzY2QyYzk4YdgCBeACAQ&sid=ccf9f578c3c0fdbc814b7dedc719698d&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=168&dest_type=country&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=country&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=19cc41ee626800d4&ss=Philippines&ss_all=0&ss_raw=Philippines&ssb=empty&sshis=0&top_ufis=1&rows=2000'
response=requests.get(url,headers=headers)
soup=BeautifulSoup(response.content,'lxml')
#print(soup.select('.a-carousel-card')[0].get_text())
for item in soup.select('.sr_property_block'):
	try:
		print('----------------------------------------')
		print(item.select('.sr-hotel__name')[0].get_text().strip())
		print(item.select('.hotel_name_link')[0]['href'])
		print(item.select('.bui-review-score__badge')[0].get_text().strip())
		print(item.select('.bui-review-score__text')[0].get_text().strip())
		print(item.select('.bui-review-score__title')[0].get_text().strip())
		print(item.select('.hotel_image')[0]['data-highres'])
 
		print(item.select('.bui-price-display__value')[0].get_text().strip())
		print('----------------------------------------')
	except Exception as e:
		#raise e
		print('')
# Out:
# ----------------------------------------
# CounTess Pension House
#
# /hotel/ph/countess-pension-house.en-gb.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuAKB_5eJBsACAdICJDE2NWU4YTM3LTg5NjMtNDI2Yy05NWFiLTAzY2EzY2QyYzk4YdgCBeACAQ&sid=4b119241b41a16556496a38617ee5da9&dest_id=168&dest_type=country&group_adults=2&group_children=0&hapos=1&hpos=1&no_rooms=1&sr_order=popularity&srepoch=1629884718&srpvid=17c64496e08d0081&ucfs=1&from=searchresults
# ;highlight_room=#hotelTmpl
# 8.5
# 71 reviews
# Very good
# https://cf.bstatic.com/xdata/images/hotel/square600/274010224.jpg?k=77707ca0e83de1aaa9ea7167c97c3546264743e443b0069aa8a65f8c213de436&o=
#
# ----------------------------------------
# OYO 802 Ka Farah's Inn
#
# ...

# %%
a = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuAKB_5eJBsACAdICJDE2NWU4YTM3LTg5NjMtNDI2Yy05NWFiLTAzY2EzY2QyYzk4YdgCBeACAQ&sid=ccf9f578c3c0fdbc814b7dedc719698d&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=168&dest_type=country&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=country&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=560c44468c0e0074&ss=Philippines&ss_all=0&ss_raw=Philippines&ssb=empty&sshis=0&top_ufis=1&rows=25'
b = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuAKB_5eJBsACAdICJDE2NWU4YTM3LTg5NjMtNDI2Yy05NWFiLTAzY2EzY2QyYzk4YdgCBeACAQ&sid=ccf9f578c3c0fdbc814b7dedc719698d&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=168&dest_type=country&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=country&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=dc2744deace0002e&ss=Philippines&ss_raw=Philippines&ssb=empty&top_ufis=1&rows=25&offset=25'
c = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaLQBiAEBmAExuAEXyAEM2AEB6AEB-AECiAIBqAIDuAKB_5eJBsACAdICJDE2NWU4YTM3LTg5NjMtNDI2Yy05NWFiLTAzY2EzY2QyYzk4YdgCBeACAQ&sid=ccf9f578c3c0fdbc814b7dedc719698d&tmpl=searchresults&ac_click_type=b&ac_position=0&class_interval=1&dest_id=168&dest_type=country&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=country&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=2cde44e576d00004&ss=Philippines&ss_all=0&ss_raw=Philippines&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=50'
a == b
# Out:
# False
